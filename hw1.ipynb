# %% [markdown]
# # Домашнее задание 1
# ## Список фильмов

# %% [markdown]
# У Вас есть информация о названии, годе выхода, рейтинге и жанре художественных фильмов.

# %%
movies = [
    ['Побег из Шоушенка', 1994, 9.3, 'драма'],
    ['Крёстный отец', 1972, 9.2, 'криминал'],
    ['Тёмный рыцарь', 2008, 9.0, 'боевик'],
    ['Криминальное чтиво', 1994, 8.9, 'криминал'],
    ['Форрест Гамп', 1994, 8.8, 'драма']
]

# %% [markdown]
# Задание 1. Выведите название, год и рейтинг фильма строго в формате:
# ```
# 1. Побег из Шоушенка (1994) — рейтинг: 9.3
# 2. Крёстный отец (1972) — рейтинг: 9.2
# 3. Тёмный рыцарь (2008) — рейтинг: 9.0
# ```

# %% [markdown]
# Задание 2. Выведите:
# - общее количество фильмов в коллекции,
# - количество боевиков,
# - средний рейтинг,
# - название самого старого фильма,
# - навзание фильма с самым высоким рейтингом.
#
# Выведите указанную выше статистику с использованием f-строки.

# %% [markdown]
# Задание 3. Найдите все фильмы, название которых начинается на определённую букву (запросите букву у пользователя с клавиатуры). Дайте пользователю возможность ввести букву в любом регистре. Если фильмов, начинающихся с такой буквы, нет, выведите сообщение «Фильмы не найдены».

# %% [markdown]
# Задание 4. Запросите у пользователя год. Найдите все фильмы, выпущенные в указанный год или позднее.

# %% [markdown]
# Задание 5. Найдите фильм по ключевому слову в названии (регистронезависимый поиск). Подсказка: используйте `in` для проверки наличия подстроки в строке.

# %% [markdown]
# Задание 6. Создайте список только названий фильмов, используя списковые включения. Отсортируйте его по алфавиту. Соберите отсортированные названия фильмов в одну строку через точку с запятой и выведите эту строку.

# %% [markdown]
# Задание 7. Добавьте как минимум 3 новых фильма в список movies.

# %% [markdown]
# Задание 8. Создайте список кортежей (название, год) для каждого фильма и выведите его.

# %% [markdown]
# Задание 9. Найдите первый фильм, рейтинг которого выше 9.0, и выведите его. Используйте break, чтобы остановить перебор фильмов.

# %% [markdown]
# Задание 10. Выведите все фильмы, кроме жанра "криминал". Используйте continue.

# %% [markdown]
# Задание 11. Используя срезы, измените порядок фильмов в списке так, чтобы они были записаны с конца.

# %% [markdown]
# Задание 12. Выведите все фильмы, вышедшие в XX веке, у которых рейтинг выше 8.0.

# %% [markdown]
# Задание 13. Выведите фильм с самым длинным названием и укажите количество слов в нём.

# %% [markdown]
# Задание 14. Пусть теперь жанр фильмов будет не просто строкой, а списком (в нашем случае с одним элементом). Бывает же много жанров у одного фильма! Теперь добавьте к любому фильму ещё один жанр в список. Например:
# ```
# movies = [
#     ['Побег из Шоушенка', 1994, 9.3, ['драма']],
#     ['Крёстный отец', 1972, 9.2, ['криминал', 'драма']]
#     ]
# ```

# %% [markdown]
# Задание 15. У Вас есть два списка: названия и рейтинг. Используя range, соотнесите информацию о каждом фильме и выведите строки вида:
# ```
# Побег из Шоушенка — 9.3
# Крёстный отец — 9.2
# ```

# %%
titles = ['Побег из Шоушенка', 'Крёстный отец', 'Тёмный рыцарь']
ratings = [9.3, 9.2, 9.0]
