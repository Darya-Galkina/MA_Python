# %% [markdown]
# # Программирование на языке Python
# # Неделя 2.

# %% [markdown]
# ## Вопросы на повторение
#
# - Что такое интерпретатор Python, а что — среда разработки.
# - Что в Python называется объектом? Из каких трёх составляющих он состоит?
# - Чем int отличается от float?
# - Какой тип данных всегда возвращает функция input()? Как преобразовать ввод в число?
# - Чем отличается = от == в Python?
#
# ## Задачи на повторение
# ### Задача 1
# Напишите программу, которая запрашивает у пользователя два числа и проверяет:
#
# - оба ли числа чётные
# - чётное ли хотя бы одно число
# - оба ли числа нечётные
#
# Результат выводите с помощью f-строк, например:
#
# ```
# Оба числа чётные: True
# Хотя бы одно чётное: True
# Оба нечётные: False
# ```

# %% [markdown]
# ### Задача 2
# Напишите программу для кинотеатра, которая:
#
# Запрашивает возраст пользователя и наличие студенческого билета (yes/no).
# - Если возраст меньше 12 — билет бесплатный.
# - Если возраст от 12 до 17 — билет 300 руб.
# - Если возраст 18 и старше и есть студенческий — 350 руб., иначе — 500 руб.
#
# Программа возвращает цену билета.

# %% [markdown]
# ### Задача 3
#
# Напишите программу, которая запрашивает у пользователя пароль и проверяет, что:
# - Длина пароля не меньше 8 символов
# - В пароле есть хотя бы одна цифра
# - В пароле есть хотя бы одна заглавная буква
#
# Если все условия выполнены — вывести «Пароль надёжный».
#
# Используйте методы .isdigit(), .isupper() и функцию len().

# %% [markdown]
# Другие полезные методы строк:

# %%
text = "  Привет, мир!  "

text.strip()      # убрать пробелы в начале и конце
# Out:
# 'Привет, мир!'

# %%
text.lower()      # все буквы маленькие
# Out:
# '  привет, мир!  '

# %%
text.upper()      # все буквы большие
# Out:
# '  ПРИВЕТ, МИР!  '

# %%
text.replace("мир", "Python")  # замена подстроки
# Out:
# '  Привет, Python!  '

# %%
text.startswith("При")  # проверка начала строки
# Out:
# False

# %%
text.endswith("!")      # проверка конца строки
# Out:
# False

# %% [markdown]
# ## Методы строк .join() и .split()

# %% [markdown]
# Представьте, что нам нужно посчитать количество слов в тексте. Для этого нам, вероятнее всего, придётся придумать правило, как делить этот текст. Самый простой способ — поделить по пробелам.
#
# Для этого воспользуемся методом .split():

# %%
text_1 = 'Лев Толстой очень любил играть на балалайке (и, конечно, детей), но не умел. Бывало, пишет роман «Война и мир», а сам думает: "Тень-дер-день-тер-тер-день-день-тень". Или: "Брам-пам-дам-дарарам-пам-пам".'
text_split = text_1.split(" ")
print(text_split)
print(type(text_split))
# Out:
# ['Лев', 'Толстой', 'очень', 'любил', 'играть', 'на', 'балалайке', '(и,', 'конечно,', 'детей),', 'но', 'не', 'умел.', 'Бывало,', 'пишет', 'роман', '«Война', 'и', 'мир»,', 'а', 'сам', 'думает:', '"Тень-дер-день-тер-тер-день-день-тень".', 'Или:', '"Брам-пам-дам-дарарам-пам-пам".']
# <class 'list'>

# %% [markdown]
# Метод split разделил строку на коллекцию строк, которые теперь лежат в объекте СПИСОК (list). Список можно склеить обратно в строку методом .join():

# %%
text_joined = " ".join(text_split)
print(text_joined)
print(text_joined == text_1)
# Out:
# Лев Толстой очень любил играть на балалайке (и, конечно, детей), но не умел. Бывало, пишет роман «Война и мир», а сам думает: "Тень-дер-день-тер-тер-день-день-тень". Или: "Брам-пам-дам-дарарам-пам-пам".
# True

# %% [markdown]
# ## Типы данных: списки (list)

# %% [markdown]
# Что может храниться в списке? Любой тип данных и даже коллекции данных.

# %%
list_1 = ["биба", "Боба", 5, True, [1, 2]]

# %% [markdown]
# А что можно делать с элементами списка?
# 1. Брать элемент по индексу

# %%
# брать элемент по индексу
list_1[0] # ДА, в питоне нумерация начинается с нуля, то есть нулевой элемент - это на самом деле первый элемент
# Out:
# 'биба'

# %%
# а так можно взять последний элемент
print(list_1[-1])
# и любой по счёту справа
print(list_1[-3])
# Out:
# [1, 2]
# 5

# %%
# кстати, со строками так тоже можно, потому что строка - это членимый набор символов
"чмж"[-1]

# %% [markdown]
# 2. Брать срез списка

# %%
list_1[1:4] # обратите внимание, что четвёртый элемент НЕ включается
# Out:
# ['Боба', 5, True]

# %%
# срез строки тоже можно взять
"Горит костёр рябины красной"[0:5]
# Out:
# 'Горит'

# %%
# срез строки тоже можно взять
"Горит костёр рябины красной"[:5] # от начала до 4
# Out:
# 'Горит'

# %%
# срез строки тоже можно взять
"Горит костёр рябины красной"[-7:] # с седьмой с конца до конца
# Out:
# 'красной'

# %% [markdown]
# 3. Сортировать списки

# %%
sorted([1, 6, 9, 3])
# Out:
# [1, 3, 6, 9]

# %%
for_sort = [1, 6, 9, 3]
sorted(for_sort, reverse=True)
# Out:
# [9, 6, 3, 1]

# %%
sorted(['a', 'w', 'bc', 'j'])
# Out:
# ['a', 'bc', 'j', 'w']

# %% [markdown]
# 4. Добавлять новые элементы в конец списка

# %%
list_1 = [1, 2, 3]
list_1.append(122)
list_1
# Out:
# [1, 2, 3, 122]

# %% [markdown]
# 5. Считать кол-во тех или иных элементов в списке и возвращать индекс первого искомого элемента.

# %%
list_1.count(1)
# Out:
# 1

# %%
list_1.index(122)
# Out:
# [1, 2, 3, 122, 122, 122, 122]
# 3

# %% [markdown]
# 6. Расширять список другим списком

# %%
list_2 = ['a', 'b']
list_1.extend(list_2)
list_1
# Out:
# [1, 2, 3, 122, 'a', 'b']

# %% [markdown]
# 7. Итерироваться по элементам списка - то есть последовательно проходиться по элементам списка. Как это сделать — узнаем в следующем разделе.

# %% [markdown]
# ## Задание
#
# Дан список. Выполните без использования циклов:
#
# - Выведите первый элемент
# - Выведите первую букву первого элемента
# - Выведите последний элемент (используя отрицательный индекс)
# - Выведите элементы с индексами со 2 по 4 (включительно)
# - Выведите элементы с индексами 1 по 5 с шагом 2
# - Выведите элементы с конца, начиная с предпоследнего
# - Выведите список в обратном порядке (срезом)
# - Выведите отсортированный в алфавитном порядке список

# %%
items = ['яблоко', 'банан', 'апельсин', 'груша', 'киви', 'манго', 'виноград']
pass

# %% [markdown]
# ## Цикл `for`. Операторы `break` и `continue`

# %% [markdown]
# Цикл `for` буквально можно воспринимать следующим образом: `для каждого элемента последовательности сделай что-то`. Под последовательностью здесь понимается <b>итерируемый объект</b> т.е. буквально тот, который вы можете растащить на части (например, строку можно раcтащить на символы, список — на элементы списка, кортеж — на элементы кортежа, словарь — на пары ключ-значение).

# %%
years = ['1258', '1658', '1729', '982'] 

for y in years: # для каждого элемента в years
    print(y) # печатаем этот элемент
# Out:
# 1258
# 1638
# 1729
# 982

# %% [markdown]
# Подумайте: что сейчас хранится в переменной `y`?
#
# Иногда мы ищем что-то конкретное в списке. Тогда нам можно останоится, как только мы нашли, что искали.

# %%
# break — досрочно выйти из цикла
words = ["собака", "ночь", "инженер", "речь", "фирма"]
# ищем слово из четырёх букв
for word in words: 
    if len(word) == 4:
        print(word)
        break
# Out:
# ночь

# %%
# а теперь ищем все слова длиннее четырёх букв

# continue — пропустить итерацию

for word in words: 
    if len(word) == 4:
        continue # то есть продолжай идти по списку дальше
    else:
        print(word)

# %% [markdown]
# ## Списковые включения

# %% [markdown]
# Представим, что нам нужно выбрать только те элементы списка, которые удовлетворяют какому-то условию, и сохранить их к новый список. Для этого надо пройтись по всем элементам списка, проверить, удавлетворяют ли они условию, а затем добавить их в новый список.
#
# Сохраним из списка слов все слова третьего склонения и укажем им склонение через нижнее подчёркивание.

# %%
words = ["собака", "ночь", "инженер", "речь", "фирма"]
decl_3 = []
for word in words:
    if word.endswith("ь"):
        decl_3.append(word + "_3")
decl_3
# Out:
# ['ночь_3', 'речь_3']

# %%
# более короткий вариант, который называется "списковые включения"
decl_3 = [word + "_3" for word in words if word.endswith("ь")]
decl_3
# Out:
# ['ночь_3', 'речь_3']

# %% [markdown]
# ## Задание
# Сделайте список длин слов в списке words.

# %%
words = ['Python', 'список', 'включение', 'код', 'программирование']

# %% [markdown]
# ## Функции `range()` и `enumerate()`. Кортежи
# А как изменять элементы списка? Нужно уметь по ним итерироваться и обращаться по индексу к отдельным элементам. То есть нужно знать и индекс, и значение для каждого из элементов в списке при обходе этого спика циклом. Как создать набор индексов, то есть набор чисел от 0 до len(list)? Тут есть два способа:
#
# 1. функция `range()`
# 2. функция `enumerate()`
#
# `range()` буквально создает диапазон значений от и до (даже может сделать его с определенным шагом). При работе с ней нужно запомнить следующее:
#
#    `range(START, STOP, STEP)`
#
#    + `START` — начало нашего диапазона (дефолтно 0)
#    + `STOP` — конец нашего диапазона (не включается!)
#    + `STEP` — шаг, с которым мы идем (дефолтно 1)

# %%
# например, сделаем диапазон целых чисел от 1 до 10 с шагом 2 
# то есть возьем все нечетные числа от 1 до 10
for i in range(1, 11, 2): # 11 снова не включается
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
# значения, которые можно подставить вместо «индексов» можно создать так: 
years = ['1258', '1658', '1729', '982'] 
for i in range(len(years)): 
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %% [markdown]
# ## Задание
# Выведите сумму всех чисел, кратных 7, в диапазоне от 0 до 100.

# %% [markdown]
# Функция `enumerate()` вернет нам пару индекс-элемент, впредставленную в виде кортежа.
#
# Кортеж - это упорядоченная неизменяемая коллекция элементов, которую тоже можно индексировать. Он записывается в круглых скобочках. Кстати, если функция возвращает два значения, делает она это в виде кортежа.

# %%
for i in enumerate(years):
    print(i)
    print(f'Индексу {i[0]} соответствует элемент {i[1]}') # так можно разбить эту пару
# Out:
# (0, '1258')
# Индексу 0 соответствует элемент 1258
# (1, '1638')
# Индексу 1 соответствует элемент 1638
# (2, '1729')
# Индексу 2 соответствует элемент 1729
# (3, '982')
# Индексу 3 соответствует элемент 982

# %% [markdown]
# Ещё немного про кортежи:

# %%
coordinates = (10, 20)
x, y = coordinates  # распаковка
print(x, y)
# Out:
# 10 20

# %%
# то есть в цикле выше мы можем распаковать кортеж на две переменные - индекс и значение

for index, value in enumerate(years):
    print(f'Индексу {index} соответствует элемент {value}') # так можно разбить эту пару
# Out:
# Индексу 0 соответствует элемент 1258
# Индексу 1 соответствует элемент 1658
# Индексу 2 соответствует элемент 1729
# Индексу 3 соответствует элемент 982

# %% [markdown]
# Давайте поменяем строки на целые числа в нашем списке `years`.

# %%
print(years)

for i in range(len(years)):
    years[i] = int(years[i]) 

print(years)
# Out:
# ['1258', '1638', '1729', '982']
# [1258, 1638, 1729, 982]

# %% [markdown]
# ## Практика 1
#
# Дан список студентов.
# С помощью enumerate() выведите нумерованный список (начиная с 1) в формате:
#
# ```
# 1. Анна
# 2. Борис
# 3. Виктория
# 4. Глеб
# 5. Дарья
# ```

# %%
students = ["Анна", "Борис", "Виктория", "Глеб", "Дарья"]
pass

# %% [markdown]
# ## Практика 2
#
# Выведите индексы элементов, значение которые больше или равно 4.

# %%
grades = [4, 5, 3, 2, 5, 4, 5, 3, 4, 2, 5, 4]
pass

# %% [markdown]
# ## Практика 3
# У вас есть список списков, в котором указаны возраст, рост и вес трёх человек.
# Найдите самого высокого человека, средний возраст группы, их общий вес.
#
# Вам понадобятся функции max() и mean().

# %%
data = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

# %% [markdown]
# ## Практика 4
# Напишите программу, которая считает:
# - количество слов в тексте,
# - количество уникальных слов,
# - самое длинное слово,
# - самое часто встречающееся слово.
# Ответ выведите с использованием f-строки.
#
#
# Необходимо убрать знаки препинания и привести всё к нижнему регистру.

# %%
text = """В лесу родилась ёлочка, в лесу она росла.
Зимой и летом стройная, зелёная была.
Метель ей пела песенку: спи, ёлочка, бай-бай!
Мороз снежком укутывал: смотри, не замерзай!
Трусишка зайка серенький под ёлочкой скакал.
Порою волк, сердитый волк, рысцою пробегал.
В лесу родилась ёлочка, в лесу она росла.
Зимой и летом стройная, зелёная была.
Теперь она нарядная на праздник к нам пришла,
И много-много радости детишкам принесла."""

# %% [markdown]
# ____
# ## Цикл `while`

# %% [markdown]
# В языке программирования Python есть два основных типа циклов – циклы `while` и `for`.
#
# Как выглядит синтаксис цикла `while`?
#
# ```
# while <условие>:
#     <блок кода, который исполняется, пока выполняется логическое условие выше>
# ```
#
# Идея в том, чтобы цикл не заканчивался до тех пор, пока не будет удовлетворяться какое-то условие. Например, будем запрашивать у пользователя пароль до тех пор, пока он не будет удовлетворять условию.

# %%
password = ""

while len(password) < 4:
    password = input("Придумайте пароль (4 символа): ")
    if len(password) < 4:
        print(f"Слишком короткий!")
    if len(password) > 4:
        print(f"Слишком длинный!")

print("✅ Пароль принят!")

# %% [markdown]
# ## Задание
# Компьютер загадывает число от 1 до 100. У игрока есть ровно 7 попыток, чтобы угадать его. Программа даёт подсказки "больше" или "меньше".

# %%
import random

# 1. Компьютер загадывает число от 1 до 100
secret = random.randint(1, 100)
attempts = 0
max_attempts = 7

print("Я загадал число от 1 до 100!")
print(f"У тебя {max_attempts} попыток, чтобы угадать!")

pass
# Out:
# Я загадал число от 1 до 100!
# У тебя 7 попыток, чтобы угадать!
